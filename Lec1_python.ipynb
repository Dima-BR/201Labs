# %% [markdown]
# <a href="https://colab.research.google.com/github/Dima-BR/201Labs/blob/master/Lec1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This is the first lec with Python and notebook**
